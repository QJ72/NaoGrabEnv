# %%
joints = ['HeadYaw', 'LHipYawPitch', 'LShoulderPitch', 'RHipYawPitch', 'RShoulderPitch', 'HeadPitch', 'LHipRoll', 'LShoulderRoll', 'RHipRoll', 'RShoulderRoll', 'LHipPitch', 'LElbowYaw', 'RHipPitch', 'RElbowYaw', 'LKneePitch', 'LElbowRoll', 'RKneePitch', 'RElbowRoll', 'LAnklePitch', 'LWristYaw', 'RAnklePitch', 'RWristYaw', 'LAnkleRoll', 'LFinger11', 'LFinger21', 'LHand', 'LThumb1', 'RAnkleRoll', 'RFinger11', 'RFinger21', 'RHand', 'RThumb1', 'LFinger12', 'LFinger22', 'LThumb2', 'RFinger12', 'RFinger22', 'RThumb2', 'LFinger13', 'LFinger23', 'RFinger13', 'RFinger23']

# %%
for name in [
            "LShoulderPitch", "LShoulderRoll", 
            "LElbowYaw", "LElbowRoll", "LWristYaw","LHand",  
            "LFinger11", "LFinger21", "LThumb1", "LFinger12",
            "LFinger22", "LFinger13", "LFinger23", "LThumb2"] :
    print(f" joint : {name} {joints.index(name)}")
# Out:
#  joint : LShoulderPitch 2
#  joint : LShoulderRoll 7
#  joint : LElbowYaw 11
#  joint : LElbowRoll 15
#  joint : LWristYaw 19
#  joint : LHand 25
#  joint : LFinger11 23
#  joint : LFinger21 24
#  joint : LThumb1 26
#  joint : LFinger12 32
#  joint : LFinger22 33
#  joint : LFinger13 38
#  joint : LFinger23 39
#  joint : LThumb2 34
